# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=100, n_features=1, noise=20)
reg = LinearRegression().fit(X_test,y_test)
reg.score(X_test,y_test)
reg.coef_
reg.intercept_
# Out:
# -1.0359567347451486

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
import pandas as pd
data={'X':x,"y":y}
df=pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X           y
# 0     [1.0481011475440336]   56.917467
# 1      [2.269223072870973]  162.892358
# 2    [-0.2874404235206107]  -25.432045
# 3     [0.3424824923374721]   28.336388
# 4   [-0.47038121470601546]  -18.642335
# 5     [0.5277917695490552]   22.776621
# 6      [-1.35899603239259] -146.770105
# 7    [-1.0698412326477615]  -56.413153
# 8     [1.4003665373030576]   83.197290
# 9    [-0.5319154769553261]  -38.101809
# 10   [-0.7826850513178071]  -46.361529
# 11   [0.30648081983901665]   74.281219
# 12   [0.19438810626158928]   10.968939
# 13   [-0.4173585561912754]  -27.250454
# 14   [-0.7455158666046515]  -60.899477
# 15    [-2.038145973183138] -100.641262
# 16    [1.8063627070793726]   79.332981
# 17   [-0.4011530271702742]  -31.129210
# 18    [0.6311485400145657]   39.538126
# 19   [-0.9981212909294572]  -81.615598

# %%
pyplot.scatter(X_test,y_test)
y_plot=reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test,y_plot,color="red")
pyplot.show()
