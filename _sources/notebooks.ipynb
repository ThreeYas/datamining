# %% [markdown]
# # Tugas 1

# %%
# mengimpor paket pandas kemudian diberi nama alias pd
import pandas as pd
# mengimpor paket seaborn kemudian diberi nama alias sns
import seaborn as sns

# %%
# membaca dataset csv dari url
url = 'https://raw.githubusercontent.com/ThreeYas/pengangguranumur/main/pengangguran_umur.csv'
data = pd.read_csv(url)

# %%
data
# Out:
#         umur  tahun_2019  tahun_2020
# 0      15-19       26.12       24.34
# 1      20-24       15.64       16.71
# 2      25-29        7.19        9.77
# 3      30-34        3.52        5.75
# 4      35-39        2.25        4.32
# 5      40-44        2.06        3.92
# 6      45-49        1.81        3.54
# 7      50-54        1.65        3.61
# 8      55-59        1.30        3.21
# 9  60 keatas        0.68        1.70

# %%
# menunjukkan beberapa data statistik pada kolom tahun_2019
data['tahun_2019'].describe()
# Out:
# count    10.000000
# mean      6.222000
# std       8.308461
# min       0.680000
# 25%       1.690000
# 50%       2.155000
# 75%       6.272500
# max      26.120000
# Name: tahun_2019, dtype: float64

# %%
# menunjukkan beberapa data statistik pada kolom tahun_2020
data['tahun_2020'].describe()
# Out:
# count    10.000000
# mean      7.687000
# std       7.318637
# min       1.700000
# 25%       3.557500
# 50%       4.120000
# 75%       8.765000
# max      24.340000
# Name: tahun_2020, dtype: float64

# %%
# Menampilkan histogram untuk kolom tahun_2019 pada data menggunakan seaborn
sns.distplot(data['tahun_2019']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Menampilkan histogram untuk kolom tahun_2020 pada data menggunakan seaborn
sns.distplot(data['tahun_2020']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
